# %% [markdown]
# ## v2: Data Ingest Optimization Demo - Simple [UPDATED 11/19]

# %%
# First clone the RAGBuilder repo
# !git clone https://github.com/KruxAI/ragbuilder.git

# %%
from ragbuilder import RAGBuilder
from ragbuilder.config import RAGConfig, BaseConfig, DataIngestOptionsConfig, RetrievalOptionsConfig
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
builder = RAGBuilder(RAGConfig(base={
    "input_source": "lillog_agents.pdf",
    "test_dataset": "rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv",
}))

# %%
best_config, best_score, best_indexer = builder.optimize_data_ingest()
# Out:
# [16:00:26] INFO     Initialized DB logging for run_id: 1732012226                                   ]8;id=419382;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/core/callbacks.py\callbacks.py]8;;\:]8;id=303898;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/core/callbacks.py#36\36]8;;\
#            INFO     Database logging enabled                                                     ]8;id=278799;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=198186;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#34\34]8;;\
# ────────────────────────────────────────── Starting Optimization Process ──────────────────────────────────────────
# [I 2024-11-19 16:00:26,986] A new study created in memory with name: data_ingest_1732012219937
#   0%|          | 0/10 [00:00<?, ?it/s]
# Trial 0/9
# [16:00:27] INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=835364;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=827502;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 3000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=709490;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=495750;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [16:00:32] INFO     Use pytorch device_name: mps                                         ]8;id=669877;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=927188;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
#            INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=523200;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=460164;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.7655
# [I 2024-11-19 16:00:41,657] Trial 0 finished with value: 0.7654710897803307 and parameters: {'chunk_size': 3000}. Best is trial 0 with value: 0.7654710897803307.
# Trial 1/9
# [16:00:41] INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=667468;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=259541;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 3000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.7654710897803307                      ]8;id=89989;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=317402;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#61\61]8;;\
# [I 2024-11-19 16:00:41,663] Trial 1 finished with value: 0.7654710897803307 and parameters: {'chunk_size': 3000}. Best is trial 0 with value: 0.7654710897803307.
# Trial 2/9
#            INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=779147;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=253867;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=458201;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=290115;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [16:00:45] INFO     Use pytorch device_name: mps                                         ]8;id=165310;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=269936;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
#            INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=759119;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=866941;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8016
# [I 2024-11-19 16:00:52,835] Trial 2 finished with value: 0.8015819494922954 and parameters: {'chunk_size': 1500}. Best is trial 2 with value: 0.8015819494922954.
# Trial 3/9
# [16:00:52] INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=62543;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=592148;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=325934;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=318324;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [16:00:56] INFO     Use pytorch device_name: mps                                         ]8;id=558119;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=935225;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [16:00:57] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=275362;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=242222;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8155
# [I 2024-11-19 16:01:04,583] Trial 3 finished with value: 0.8154909427960714 and parameters: {'chunk_size': 500}. Best is trial 3 with value: 0.8154909427960714.
# Trial 4/9
# [16:01:04] INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=414113;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=701006;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 2500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=307909;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=522906;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [16:01:08] INFO     Use pytorch device_name: mps                                         ]8;id=93273;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=306333;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [16:01:09] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=497846;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=802563;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.7791
# [I 2024-11-19 16:01:15,490] Trial 4 finished with value: 0.7791137912869454 and parameters: {'chunk_size': 2500}. Best is trial 3 with value: 0.8154909427960714.
# Trial 5/9
# [16:01:15] INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=477823;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=813249;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8015819494922954                      ]8;id=108942;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=923678;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#61\61]8;;\
# [I 2024-11-19 16:01:15,496] Trial 5 finished with value: 0.8015819494922954 and parameters: {'chunk_size': 1500}. Best is trial 3 with value: 0.8154909427960714.
# Trial 6/9
#            INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=398448;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=206956;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 1000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=938957;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=663869;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [16:01:19] INFO     Use pytorch device_name: mps                                         ]8;id=706993;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=800281;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [16:01:20] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=944807;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=742413;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8080
# [I 2024-11-19 16:01:27,881] Trial 6 finished with value: 0.8080389504631361 and parameters: {'chunk_size': 1000}. Best is trial 3 with value: 0.8154909427960714.
# Trial 7/9
# [16:01:27] INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=288941;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=403456;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 2500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.7791137912869454                      ]8;id=799937;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=164267;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#61\61]8;;\
# [I 2024-11-19 16:01:27,887] Trial 7 finished with value: 0.7791137912869454 and parameters: {'chunk_size': 2500}. Best is trial 3 with value: 0.8154909427960714.
# Trial 8/9
#            INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=429951;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=943569;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8015819494922954                      ]8;id=432650;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=43480;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#61\61]8;;\
# [I 2024-11-19 16:01:27,891] Trial 8 finished with value: 0.8015819494922954 and parameters: {'chunk_size': 1500}. Best is trial 3 with value: 0.8154909427960714.
# Trial 9/9
#            INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=859241;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=968849;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 2500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.7791137912869454                      ]8;id=36069;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=569073;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#61\61]8;;\
# [I 2024-11-19 16:01:27,895] Trial 9 finished with value: 0.7791137912869454 and parameters: {'chunk_size': 2500}. Best is trial 3 with value: 0.8154909427960714.
# Optimization Complete!
# Best Score: 0.8155
# Best Parameters:
# {'chunk_size': 500}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=458986;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=207633;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [16:01:31] INFO     Use pytorch device_name: mps                                         ]8;id=371748;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=551788;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [16:01:32] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=661502;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=415166;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## v2 Data Ingest Optimization Demo - Advanced [UPDATED 11/19]

# %%
from ragbuilder import RAGBuilder
from ragbuilder.config import RAGConfig, BaseConfig, DataIngestOptionsConfig, RetrievalOptionsConfig
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
config = BaseConfig(
    input_source="uber_10k.pdf",
    test_dataset="rag_test_data_1726600284.375674 uber10k_shortlist.csv"
)

builder = RAGBuilder(config=RAGConfig(base=config))

# %%
import ragbuilder.data_ingest.optimization as data_ingest

# %%
data_ingest_config = DataIngestOptionsConfig(
    input_source="uber_10k.pdf",
    test_dataset="rag_test_data_1726600284.375674 uber10k_shortlist.csv",
    document_loaders=[
        {"type": "pymupdf"}, 
        {"type": "unstructured"},
        {"type": "pypdf"}
    ],
    chunking_strategies=[
        {
            "type": "RecursiveCharacterTextSplitter",
            "chunker_kwargs": {"separators": ["\n\n", "\n", " ", ""]}
        },
        {
            "type": "custom",
            "custom_class": "ragbuilder.custom_components.CustomChunker"
        },
    ],
    chunk_size={
        "min": 500,
        "max": 2000,
        "stepsize": 500
    },
    chunk_overlap=[100],
    embedding_models=[
        {
            "type": "huggingface",
            "model_kwargs": {
                "model_name": "mixedbread-ai/mxbai-embed-large-v1",
            }
        },
        {
            "type": "azure_openai",
            "model_kwargs": {
                "model": "text-embedding-3-large",
            }
        }
    ],
    vector_databases=[
        {
            "type": "chroma",
            "vectordb_kwargs": {
                'persist_directory': 'chroma_sample2',
                'collection_metadata': {'hnsw:space': 'cosine'}
            }
        }
    ],
    
    optimization={
        "n_trials": 30, 
        "n_jobs": 1,
        "study_name": "lillog_agents_study",
        "optimization_direction": "maximize"
    },
    evaluation_config={
        "type": "similarity",
        "evaluator_kwargs": {
            "top_k": 3,
            "relevance_threshold": 0.2,
            "position_weights": [1.0, 0.5, 0.3]  # More weight to top results
        }
    },
    
    # Logging configuration
    log_config={
        "log_level": 20,  # INFO level
        "show_progress_bar": True,
        "verbose": True
    },
    
    database_logging=True,
    database_path="lillog_agents_eval.db"
)

# %%
best_config, best_score, best_indexer = builder.optimize_data_ingest(data_ingest_config)
# Out:
# [15:08:42] INFO     Starting data ingestion optimization                                              ]8;id=498182;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/core/builder.py\builder.py]8;;\:]8;id=29023;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/core/builder.py#29\29]8;;\
#            INFO     Loaded environment variables from .env                                              ]8;id=213039;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/core/utils.py\utils.py]8;;\:]8;id=22558;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/core/utils.py#17\17]8;;\
#            INFO     Initialized DB logging for run_id: 1732009122                                   ]8;id=105630;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/core/callbacks.py\callbacks.py]8;;\:]8;id=544336;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/core/callbacks.py#36\36]8;;\
#            INFO     Database logging enabled                                                     ]8;id=420854;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=410211;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#34\34]8;;\
# ────────────────────────────────────────── Starting Optimization Process ──────────────────────────────────────────
# [I 2024-11-19 15:08:42,467] A new study created in memory with name: lillog_agents_study
#   0%|          | 0/30 [00:00<?, ?it/s]
# Trial 0/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=422669;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=896439;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYMUPDF: 'pymupdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/0',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# class_path:  ragbuilder.custom_components.CustomChunker
# [15:08:43] INFO     Load pretrained SentenceTransformer:                                 ]8;id=503296;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=724749;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [15:08:49] INFO     Use pytorch device_name: mps                                         ]8;id=881190;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=445587;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [15:08:50] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=41237;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=117219;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# [15:08:51] INFO     Backing off send_request(...) for 0.8s (requests.exceptions.ConnectionError:     ]8;id=765592;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/backoff/_common.py\_common.py]8;;\:]8;id=514943;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/backoff/_common.py#105\105]8;;\
#                     HTTPSConnectionPool(host='us.i.posthog.com', port=443): Max retries exceeded
#                     with url: /batch/ (Caused by
#                     NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x347fc9b50>:
#                     Failed to resolve 'us.i.posthog.com' ([Errno 8] nodename nor servname provided,
#                     or not known)")))
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8241
# [I 2024-11-19 15:09:42,631] Trial 0 finished with value: 0.8241187054959555 and parameters: {'document_loader_index': 0, 'chunking_strategy_index': 1, 'chunk_size': 500, 'embedding_model_index': 0}. Best is trial 0 with value: 0.8241187054959555.
# Trial 1/29
# [15:09:42] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=164768;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=996279;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYMUPDF: 'pymupdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs={'separators': ['\n\n',
#                     '\n', ' ', '']}, custom_class=None), 'chunk_overlap': 100, 'chunk_size':
#                     1000, 'embedding_model': EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE:
#                     'huggingface'>, model_kwargs={'model_name':
#                     'mixedbread-ai/mxbai-embed-large-v1'}, custom_class=None),
#                     'vector_database': VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/1',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=257663;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=860504;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [15:09:47] INFO     Use pytorch device_name: mps                                         ]8;id=972019;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=642214;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
#            INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=991124;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=962370;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8202
# [I 2024-11-19 15:10:33,915] Trial 1 finished with value: 0.8202395822320666 and parameters: {'document_loader_index': 0, 'chunking_strategy_index': 0, 'chunk_size': 1000, 'embedding_model_index': 0}. Best is trial 0 with value: 0.8241187054959555.
# Trial 2/29
# [15:10:33] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=268604;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=748968;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#190\190]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYPDF: 'pypdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 1000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.AZURE_OPENAI: 'azure_openai'>,
#                     model_kwargs={'model': 'text-embedding-3-large'}, custom_class=None),
#                     'vector_database': VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/2',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# class_path:  ragbuilder.custom_components.CustomChunker
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [W 2024-11-19 15:10:48,517] Trial 2 failed with parameters: {'document_loader_index': 2, 'chunking_strategy_index': 1, 'chunk_size': 1000, 'embedding_model_index': 1} because of the following error: RateLimitError("Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2024-02-01 have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 86400 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}").
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py", line 66, in objective
#     pipeline.run()
#   File "/Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/pipeline.py", line 208, in run
#     self.indexer = self._create_indexer(chunks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/pipeline.py", line 165, in _create_indexer
#     return vectordb_class.from_documents(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/langchain_community/vectorstores/chroma.py", line 790, in from_documents
#     return cls.from_texts(
#            ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/langchain_community/vectorstores/chroma.py", line 754, in from_texts
#     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/langchain_community/vectorstores/chroma.py", line 276, in add_texts
#     embeddings = self._embedding_function.embed_documents(texts)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/langchain_openai/embeddings/base.py", line 526, in embed_documents
#     return self._get_len_safe_embeddings(texts, engine=engine)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/langchain_openai/embeddings/base.py", line 424, in _get_len_safe_embeddings
#     response = self.client.create(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/resources/embeddings.py", line 124, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py", line 1270, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py", line 947, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py", line 1036, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py", line 1085, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py", line 1036, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py", line 1085, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py", line 1051, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2024-02-01 have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 86400 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# [W 2024-11-19 15:10:48,522] Trial 2 failed with value None.
# ---------------------------------------------------------------------------
#
# RateLimitError                            Traceback (most recent call last)
#
# Cell In[7], line 1
#
# ----> 1 best_config, best_score, best_indexer = builder.optimize_data_ingest(data_ingest_config)
#
#
#
# File ~/KruxAI/ragbuilder/src/ragbuilder/core/builder.py:30, in RAGBuilder.optimize_data_ingest(self, config)
#
#      27     self.config.data_ingest = DataIngestConfig(self.config.base)
#
#      29 self.logger.info("Starting data ingestion optimization")
#
# ---> 30 best_config, best_score, best_index = run_optimization_from_dict(
#
#      31     self.config.data_ingest.model_dump()
#
#      32 )
#
#      34 self._optimized_store = best_index
#
#      35 return best_config, best_score, best_index
#
#
#
# File ~/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py:255, in run_optimization_from_dict(options_config_dict)
#
#     253 def run_optimization_from_dict(options_config_dict: dict):
#
#     254     options_config = DataIngestOptionsConfig(**options_config_dict)
#
# --> 255     return _run_optimization_core(options_config)
#
#
#
# File ~/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py:241, in _run_optimization_core(options_config)
#
#     238     evaluator = SimilarityEvaluator(options_config.test_dataset, options_config.evaluation_config)
#
#     240 optimizer = Optimizer(options_config, evaluator)
#
# --> 241 best_config, best_score = optimizer.optimize()
#
#     243 # TODO: Revisit this to use cache to avoid running the pipeline twice
#
#     244 best_pipeline = DataIngestPipeline(best_config)
#
#
#
# File ~/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py:106, in Optimizer.optimize(self)
#
#      95     optuna.delete_study(study_name=self.options_config.optimization.study_name, storage=self.options_config.optimization.storage)
#
#      97 study = optuna.create_study(
#
#      98     storage=self.options_config.optimization.storage,
#
#      99     study_name=self.options_config.optimization.study_name,
#
#    (...)
#
#     103     pruner=optuna.pruners.MedianPruner()
#
#     104 )
#
# --> 106 study.optimize(
#
#     107     objective,
#
#     108     n_trials=self.options_config.optimization.n_trials,
#
#     109     n_jobs=self.options_config.optimization.n_jobs,
#
#     110     timeout=self.options_config.optimization.timeout,
#
#     111     show_progress_bar=self.options_config.log_config.show_progress_bar
#
#     112 )
#
#     114 console.print(f"[heading]Optimization Complete![/heading]")
#
#     115 console.print(f"[success]Best Score:[/success] [value]{study.best_value:.4f}[/value]")
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#
#     373 def optimize(
#
#     374     self,
#
#     375     func: ObjectiveFuncType,
#
#    (...)
#
#     382     show_progress_bar: bool = False,
#
#     383 ) -> None:
#
#     384     """Optimize an objective function.
#
#     385
#
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#
#    (...)
#
#     473             If nested invocation of this method occurs.
#
#     474     """
#
# --> 475     _optimize(
#
#     476         study=self,
#
#     477         func=func,
#
#     478         n_trials=n_trials,
#
#     479         timeout=timeout,
#
#     480         n_jobs=n_jobs,
#
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#
#     482         callbacks=callbacks,
#
#     483         gc_after_trial=gc_after_trial,
#
#     484         show_progress_bar=show_progress_bar,
#
#     485     )
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#
#      61 try:
#
#      62     if n_jobs == 1:
#
# ---> 63         _optimize_sequential(
#
#      64             study,
#
#      65             func,
#
#      66             n_trials,
#
#      67             timeout,
#
#      68             catch,
#
#      69             callbacks,
#
#      70             gc_after_trial,
#
#      71             reseed_sampler_rng=False,
#
#      72             time_start=None,
#
#      73             progress_bar=progress_bar,
#
#      74         )
#
#      75     else:
#
#      76         if n_jobs == -1:
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#
#     157         break
#
#     159 try:
#
# --> 160     frozen_trial = _run_trial(study, func, catch)
#
#     161 finally:
#
#     162     # The following line mitigates memory problems that can be occurred in some
#
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#
#     164     # Please refer to the following PR for further details:
#
#     165     # https://github.com/optuna/optuna/pull/325.
#
#     166     if gc_after_trial:
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#
#     241         assert False, "Should not reach."
#
#     243 if (
#
#     244     frozen_trial.state == TrialState.FAIL
#
#     245     and func_err is not None
#
#     246     and not isinstance(func_err, catch)
#
#     247 ):
#
# --> 248     raise func_err
#
#     249 return frozen_trial
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#
#     196     try:
#
# --> 197         value_or_values = func(trial)
#
#     198     except exceptions.TrialPruned as e:
#
#     199         # TODO(mamu): Handle multi-objective cases.
#
#     200         state = TrialState.PRUNED
#
#
#
# File ~/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py:66, in Optimizer.optimize.<locals>.objective(trial)
#
#      64 self.logger.debug(f"Running pipeline with config: {config}")
#
#      65 pipeline = DataIngestPipeline(config)
#
# ---> 66 pipeline.run()
#
#      68 avg_score, question_details = self.evaluator.evaluate(pipeline)
#
#      70 metrics = self._calculate_aggregate_metrics(question_details)
#
#
#
# File ~/KruxAI/ragbuilder/src/ragbuilder/data_ingest/pipeline.py:208, in DataIngestPipeline.run(self)
#
#     205     raise ValueError("No chunks were generated from the documents")
#
#     207 status.update("[status]Creating vector index...[/status]")
#
# --> 208 self.indexer = self._create_indexer(chunks)
#
#     210 console.print("[success]✓ Pipeline execution complete![/success]")
#
#     211 return self.indexer
#
#
#
# File ~/KruxAI/ragbuilder/src/ragbuilder/data_ingest/pipeline.py:165, in DataIngestPipeline._create_indexer(self, chunks)
#
#     159         vectordb_kwargs['collection_name'] = f"ragbuilder_{int(time.time())}_{random.randint(1, 1000)}"
#
#     160     # TODO: Handle the scenario where user has specified a collection name, and we want to avoid upserts/ dups in the collection
#
#     161     # elif 'client_settings' not in vectordb_kwargs:
#
#     162     #     import chromadb
#
#     163     #     vectordb_kwargs['client_settings'] = chromadb.config.Settings(allow_reset=True, persist_directory=vectordb_kwargs.get('persist_directory', './chroma'))
#
# --> 165     return vectordb_class.from_documents(
#
#     166         chunks,
#
#     167         self.embedder,
#
#     168         **vectordb_kwargs
#
#     169     )
#
#     171 # print("Vector Database: ", vectordb_class)
#
#     172 # print("Vector Database Kwargs: ", self.config.vector_database.vectordb_kwargs)
#
#     173 return vectordb_class.from_documents(
#
#     174     chunks,
#
#     175     self.embedder,
#
#     176     **(self.config.vector_database.vectordb_kwargs or {})
#
#     177 )
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/langchain_community/vectorstores/chroma.py:790, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#
#     788 texts = [doc.page_content for doc in documents]
#
#     789 metadatas = [doc.metadata for doc in documents]
#
# --> 790 return cls.from_texts(
#
#     791     texts=texts,
#
#     792     embedding=embedding,
#
#     793     metadatas=metadatas,
#
#     794     ids=ids,
#
#     795     collection_name=collection_name,
#
#     796     persist_directory=persist_directory,
#
#     797     client_settings=client_settings,
#
#     798     client=client,
#
#     799     collection_metadata=collection_metadata,
#
#     800     **kwargs,
#
#     801 )
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/langchain_community/vectorstores/chroma.py:754, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#
#     748         chroma_collection.add_texts(
#
#     749             texts=batch[3] if batch[3] else [],
#
#     750             metadatas=batch[2] if batch[2] else None,
#
#     751             ids=batch[0],
#
#     752         )
#
#     753 else:
#
# --> 754     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
#     755 return chroma_collection
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/langchain_community/vectorstores/chroma.py:276, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#
#     274 texts = list(texts)
#
#     275 if self._embedding_function is not None:
#
# --> 276     embeddings = self._embedding_function.embed_documents(texts)
#
#     277 if metadatas:
#
#     278     # fill metadatas with empty dicts if somebody
#
#     279     # did not specify metadata for all texts
#
#     280     length_diff = len(texts) - len(metadatas)
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:526, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#
#     523 # NOTE: to keep things simple, we assume the list may contain texts longer
#
#     524 #       than the maximum context and use length-safe embedding function.
#
#     525 engine = cast(str, self.deployment)
#
# --> 526 return self._get_len_safe_embeddings(texts, engine=engine)
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:424, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#
#     422 batched_embeddings: List[List[float]] = []
#
#     423 for i in _iter:
#
# --> 424     response = self.client.create(
#
#     425         input=tokens[i : i + _chunk_size], **self._invocation_params
#
#     426     )
#
#     427     if not isinstance(response, dict):
#
#     428         response = response.model_dump()
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/resources/embeddings.py:124, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#
#     118         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#
#     119             base64.b64decode(data), dtype="float32"
#
#     120         ).tolist()
#
#     122     return obj
#
# --> 124 return self._post(
#
#     125     "/embeddings",
#
#     126     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#
#     127     options=make_request_options(
#
#     128         extra_headers=extra_headers,
#
#     129         extra_query=extra_query,
#
#     130         extra_body=extra_body,
#
#     131         timeout=timeout,
#
#     132         post_parser=parser,
#
#     133     ),
#
#     134     cast_to=CreateEmbeddingResponse,
#
#     135 )
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py:1270, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#
#    1256 def post(
#
#    1257     self,
#
#    1258     path: str,
#
#    (...)
#
#    1265     stream_cls: type[_StreamT] | None = None,
#
#    1266 ) -> ResponseT | _StreamT:
#
#    1267     opts = FinalRequestOptions.construct(
#
#    1268         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#
#    1269     )
#
# -> 1270     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py:947, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#
#     944 else:
#
#     945     retries_taken = 0
#
# --> 947 return self._request(
#
#     948     cast_to=cast_to,
#
#     949     options=options,
#
#     950     stream=stream,
#
#     951     stream_cls=stream_cls,
#
#     952     retries_taken=retries_taken,
#
#     953 )
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py:1036, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#
#    1034 if remaining_retries > 0 and self._should_retry(err.response):
#
#    1035     err.response.close()
#
# -> 1036     return self._retry_request(
#
#    1037         input_options,
#
#    1038         cast_to,
#
#    1039         retries_taken=retries_taken,
#
#    1040         response_headers=err.response.headers,
#
#    1041         stream=stream,
#
#    1042         stream_cls=stream_cls,
#
#    1043     )
#
#    1045 # If the response is streamed then we need to explicitly read the response
#
#    1046 # to completion before attempting to access the response text.
#
#    1047 if not err.response.is_closed:
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py:1085, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#
#    1081 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#
#    1082 # different thread if necessary.
#
#    1083 time.sleep(timeout)
#
# -> 1085 return self._request(
#
#    1086     options=options,
#
#    1087     cast_to=cast_to,
#
#    1088     retries_taken=retries_taken + 1,
#
#    1089     stream=stream,
#
#    1090     stream_cls=stream_cls,
#
#    1091 )
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py:1036, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#
#    1034 if remaining_retries > 0 and self._should_retry(err.response):
#
#    1035     err.response.close()
#
# -> 1036     return self._retry_request(
#
#    1037         input_options,
#
#    1038         cast_to,
#
#    1039         retries_taken=retries_taken,
#
#    1040         response_headers=err.response.headers,
#
#    1041         stream=stream,
#
#    1042         stream_cls=stream_cls,
#
#    1043     )
#
#    1045 # If the response is streamed then we need to explicitly read the response
#
#    1046 # to completion before attempting to access the response text.
#
#    1047 if not err.response.is_closed:
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py:1085, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#
#    1081 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#
#    1082 # different thread if necessary.
#
#    1083 time.sleep(timeout)
#
# -> 1085 return self._request(
#
#    1086     options=options,
#
#    1087     cast_to=cast_to,
#
#    1088     retries_taken=retries_taken + 1,
#
#    1089     stream=stream,
#
#    1090     stream_cls=stream_cls,
#
#    1091 )
#
#
#
# File /opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/openai/_base_client.py:1051, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#
#    1048         err.response.read()
#
#    1050     log.debug("Re-raising status error")
#
# -> 1051     raise self._make_status_error_from_response(err.response) from None
#
#    1053 return self._process_response(
#
#    1054     cast_to=cast_to,
#
#    1055     options=options,
#
#    (...)
#
#    1059     retries_taken=retries_taken,
#
#    1060 )
#
#
#
# RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2024-02-01 have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 86400 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}

# %% [markdown]
# ## Data Ingest Optimization Demo - Simple

# %%
# First clone the RAGBuilder repo
# !git clone https://github.com/KruxAI/ragbuilder.git

# %%
import ragbuilder.data_ingest.optimization as data_ingest
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
demo_config = {
    "input_source": "lillog_agents.pdf",
    "test_dataset": "rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv",
}

# %%
best_config, best_score, best_indexer = data_ingest.run_optimization_from_dict(demo_config)
# Out:
# [00:56:55] INFO     Initialized DB logging for run_id: 1731439615                                   ]8;id=339053;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/callbacks.py\callbacks.py]8;;\:]8;id=333167;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/callbacks.py#36\36]8;;\
#            INFO     Database logging enabled                                                     ]8;id=344139;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=974264;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#36\36]8;;\
# ────────────────────────────────────────── Starting Optimization Process ──────────────────────────────────────────
# [I 2024-11-13 00:56:55,919] A new study created in memory with name: data_ingest_1731439614482
#   0%|          | 0/10 [00:00<?, ?it/s]
# Trial 0/9
#            INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=954150;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=886122;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 2500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
# [00:56:57] INFO     Load pretrained SentenceTransformer:                                 ]8;id=468317;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=629441;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [00:57:02] INFO     Use pytorch device_name: mps                                         ]8;id=384003;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=192013;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
#            INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=706937;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=715793;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.7791
# [I 2024-11-13 00:57:11,857] Trial 0 finished with value: 0.7791137912869454 and parameters: {'chunk_size': 2500}. Best is trial 0 with value: 0.7791137912869454.
# Trial 1/9
# [00:57:11] INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=349798;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=289472;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 2500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.7791137912869454                      ]8;id=686315;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=692768;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-13 00:57:11,865] Trial 1 finished with value: 0.7791137912869454 and parameters: {'chunk_size': 2500}. Best is trial 0 with value: 0.7791137912869454.
# Trial 2/9
#            INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=239880;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=758299;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=548611;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=176793;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [00:57:15] INFO     Use pytorch device_name: mps                                         ]8;id=702373;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=124277;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [00:57:16] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=202934;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=953133;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8016
# [I 2024-11-13 00:57:23,727] Trial 2 finished with value: 0.8015819494922954 and parameters: {'chunk_size': 1500}. Best is trial 2 with value: 0.8015819494922954.
# Trial 3/9
# [00:57:23] INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=746173;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=338555;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 3000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=105374;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=520434;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [00:57:27] INFO     Use pytorch device_name: mps                                         ]8;id=677210;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=605562;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [00:57:29] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=819534;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=558028;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.7655
# [I 2024-11-13 00:57:34,770] Trial 3 finished with value: 0.7654710897803307 and parameters: {'chunk_size': 3000}. Best is trial 2 with value: 0.8015819494922954.
# Trial 4/9
# [00:57:34] INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=856446;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=922865;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 3000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.7654710897803307                      ]8;id=468373;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=313357;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-13 00:57:34,775] Trial 4 finished with value: 0.7654710897803307 and parameters: {'chunk_size': 3000}. Best is trial 2 with value: 0.8015819494922954.
# Trial 5/9
#            INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=201418;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=926162;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 1000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=705202;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=292535;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [00:57:38] INFO     Use pytorch device_name: mps                                         ]8;id=254111;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=163462;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [00:57:39] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=584088;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=451069;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8080
# [I 2024-11-13 00:57:47,331] Trial 5 finished with value: 0.8080389504631361 and parameters: {'chunk_size': 1000}. Best is trial 5 with value: 0.8080389504631361.
# Trial 6/9
# [00:57:47] INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=213109;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=879988;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8015819494922954                      ]8;id=808090;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=159758;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-13 00:57:47,337] Trial 6 finished with value: 0.8015819494922954 and parameters: {'chunk_size': 1500}. Best is trial 5 with value: 0.8080389504631361.
# Trial 7/9
#            INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=634944;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=141408;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8015819494922954                      ]8;id=736253;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=896206;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-13 00:57:47,342] Trial 7 finished with value: 0.8015819494922954 and parameters: {'chunk_size': 1500}. Best is trial 5 with value: 0.8080389504631361.
# Trial 8/9
#            INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=358423;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=212140;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8015819494922954                      ]8;id=244896;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=746341;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-13 00:57:47,348] Trial 8 finished with value: 0.8015819494922954 and parameters: {'chunk_size': 1500}. Best is trial 5 with value: 0.8080389504631361.
# Trial 9/9
#            INFO     Trial parameters: {'input_source': 'lillog_agents.pdf', 'test_dataset':     ]8;id=511643;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=133311;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_lilianweng_gpt-4o_1721032414.736622_SEMI.csv',
#                     'document_loader': LoaderConfig(type=<ParserType.UNSTRUCTURED:
#                     'unstructured'>, loader_kwargs=None, custom_class=None),
#                     'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs=None, custom_class=None),
#                     'chunk_overlap': 100, 'chunk_size': 1000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'collection_metadata': {'hnsw:space': 'cosine'}},
#                     custom_class=None), 'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8080389504631361                      ]8;id=673252;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=184294;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-13 00:57:47,354] Trial 9 finished with value: 0.8080389504631361 and parameters: {'chunk_size': 1000}. Best is trial 5 with value: 0.8080389504631361.
# Optimization Complete!
# Best Score: 0.8080
# Best Parameters:
# {'chunk_size': 1000}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=217727;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=388798;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [00:57:51] INFO     Use pytorch device_name: mps                                         ]8;id=199763;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=301055;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [00:57:52] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=772553;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=301619;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
best_indexer.similarity_search_with_relevance_scores("What is task decomposition")
# Out:
# [(Document(metadata={'source': 'lillog_agents.pdf'}, page_content="A complicated task usually involves many steps. An agent needs to know what they are and plan\n\nahead.\n\nFAQ emojisearch.app\n\nLil'Log\n\nTask Decomposition\n\nChain of thought (CoT; Wei et al. 2022) has become a standard prompting technique for\n\nenhancing model performance on complex tasks. The model is instructed to “think step by step” to\n\nutilize more test-time computation to decompose hard tasks into smaller and simpler steps. CoT\n\ntransforms big tasks into multiple manageable tasks and shed lights into an interpretation of the\n\nmodelʼs thinking process.\n\nTree of Thoughts (Yao et al. 2023) extends CoT by exploring multiple reasoning possibilities at\n\neach step. It first decomposes the problem into multiple thought steps and generates multiple\n\nthoughts per step, creating a tree structure. The search process can be BFS (breadth-first search)\n\nor DFS (depth-first search) with each state evaluated by a classifier (via a prompt) or majority vote."),
#   0.749652624130249),
#  (Document(metadata={'source': 'lillog_agents.pdf'}, page_content='Task decomposition can be done (1) by LLM with simple prompting like "Steps for XYZ.\\n1." ,\n\n"What are the subgoals for achieving XYZ?" , (2) by using task-specific instructions; e.g. "Write\n\na story outline." for writing a novel, or (3) with human inputs.\n\nAnother quite distinct approach, LLM+P (Liu et al. 2023), involves relying on an external classical\n\nplanner to do long-horizon planning. This approach utilizes the Planning Domain Definition\n\nLanguage (PDDL) as an intermediate interface to describe the planning problem. In this process,\n\nLLM (1) translates the problem into “Problem PDDL”, then (2) requests a classical planner to\n\ngenerate a PDDL plan based on an existing “Domain PDDL”, and finally (3) translates the PDDL plan\n\nback into natural language. Essentially, the planning step is outsourced to an external tool,\n\nassuming the availability of domain-specific PDDL and a suitable planner which is common in\n\ncertain robotic setups but not in many other domains.'),
#   0.7374033331871033),
#  (Document(metadata={'source': 'lillog_agents.pdf'}, page_content='Instruction:\n\nThe AI assistant can parse user input to several tasks: [{"task": task, "id",\n\ntask_id, "dep": dependency_task_ids, "args": {"text": text, "image": URL, "audio":\n\nURL, "video": URL}}]. The "dep" field denotes the id of the previous task which\n\ngenerates a new resource that the current task relies on. A special tag "-task_id"\n\nrefers to the generated text image, audio and video in the dependency task with id\n\nas task_id. The task MUST be selected from the following options: {{ Available Task\n\nList }}. There is a logical relationship between tasks, please note their order. If\n\nthe user input can\'t be parsed, you need to reply empty JSON. Here are several\n\ncases for your reference: {{ Demonstrations }}. The chat history is recorded as {{\n\nChat History }}. From this chat history, you can find the path of the user-\n\nmentioned resources for your task planning.\n\n(2) Model selection: LLM distributes the tasks to expert models, where the request is framed as a'),
#   0.64989173412323),
#  (Document(metadata={'source': 'lillog_agents.pdf'}, page_content='ChatGPT Plugins and OpenAI API function calling are good examples of LLMs augmented with tool\n\nuse capability working in practice. The collection of tool APIs can be provided by other developers\n\n(as in Plugins) or self-defined (as in function calls).\n\nHuggingGPT (Shen et al. 2023) is a framework to use ChatGPT as the task planner to select\n\nmodels available in HuggingFace platform according to the model descriptions and summarize the\n\nresponse based on the execution results.\n\nFig. 11. Illustration of how HuggingGPT works. (Image source: Shen et al. 2023)\n\nLil\'Log\n\nThe system comprises of 4 stages:\n\n(1) Task planning: LLM works as the brain and parses the user requests into multiple tasks. There\n\nare four attributes associated with each task: task type, ID, dependencies, and arguments. They\n\nuse few-shot examples to guide LLM to do task parsing and planning.\n\nInstruction:\n\nThe AI assistant can parse user input to several tasks: [{"task": task, "id",'),
#   0.6414249539375305)]

# %% [markdown]
# ## Data Ingest Optimization Demo - Advanced

# %%
llm = ChatOpenAI(model='gpt-4o-mini', temperature=0.2)

# %%
options_config = {
    "input_source": "uber_10k.pdf",
    "test_dataset": "rag_test_data_1726600284.375674 uber10k_shortlist.csv", 
    
    # Test multiple document loaders
    "document_loaders": [
        {"type": "pymupdf"}, 
        {"type": "unstructured"},
        {"type": "pypdf"}
    ],
    
    # Test different chunking strategies
    "chunking_strategies": [
        {
            "type": "RecursiveCharacterTextSplitter",
            "chunker_kwargs": {"separators": ["\n\n", "\n", " ", ""]}
        },
        {
            "type": "custom",
            "custom_class": "ragbuilder.custom_components.CustomChunker"
            "chunker_kwargs": {"llm": }
        },
        {
            "type": "MardownHeaderSplitter",
            "chunker_kwargs": {"headers_to_split_on": [("#", "Header 1"),("##", "Header 2"),("###", "Header 3")]}
        }
    ],
    
    # Test various chunk sizes
    "chunk_size": {
        "min": 500,
        "max": 2000,
        "stepsize": 500
    },
    
    # Test different overlap sizes
    "chunk_overlap": [100],
    
    # Test multiple embedding models
    "embedding_models": [
        {
            "type": "huggingface",
            "model_kwargs": {
                "model_name": "mixedbread-ai/mxbai-embed-large-v1",
            }
        },
        {
            "type": "openai",
            "model_kwargs": {
                "model": "text-embedding-3-large",
            }
        }
    ],
    
    "vector_databases": [
        {
            "type": "chroma",
            "vectordb_kwargs": {
                'persist_directory': 'chroma_sample2',
                'collection_metadata': {'hnsw:space': 'cosine'}
            }
        }
    ],
    
    # Optimization settings
    "optimization": {
        "n_trials": 30, 
        "n_jobs": 1,
        "study_name": "lillog_agents_study",
        "optimization_direction": "maximize"
    },
    
    # Evaluation settings
    "evaluation_config": {
        "type": "similarity",
        "evaluator_kwargs": {
            "top_k": 3,
            "relevance_threshold": 0.2,
            "position_weights": [1.0, 0.5, 0.3]  # More weight to top results
        }
    },
    
    # Logging configuration
    "log_config": {
        "log_level": 20,  # INFO level
        "show_progress_bar": True,
        "verbose": True
    },
    
    # Enable database logging
    "database_logging": True,
    "database_path": "lillog_agents_eval.db"
}

# %%
best_config, best_score, best_indexer = data_ingest.run_optimization_from_dict(options_config)
# Out:
# [18:56:47] INFO     Loaded environment variables from .env                                              ]8;id=892934;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/utils.py\utils.py]8;;\:]8;id=319282;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/utils.py#13\13]8;;\
#            INFO     Initialized DB logging for run_id: 1731418007                                   ]8;id=478334;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/callbacks.py\callbacks.py]8;;\:]8;id=26010;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/callbacks.py#36\36]8;;\
#            INFO     Database logging enabled                                                     ]8;id=783925;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=969897;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#36\36]8;;\
# ────────────────────────────────────────── Starting Optimization Process ──────────────────────────────────────────
# [I 2024-11-12 18:56:47,227] A new study created in memory with name: lillog_agents_study
#   0%|          | 0/30 [00:00<?, ?it/s]
# Trial 0/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=83408;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=135834;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYPDF: 'pypdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs={'separators': ['\n\n',
#                     '\n', ' ', '']}, custom_class=None), 'chunk_overlap': 100, 'chunk_size':
#                     1000, 'embedding_model': EmbeddingConfig(type=<EmbeddingModel.OPENAI:
#                     'openai'>, model_kwargs={'model': 'text-embedding-3-large'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/0',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.6989
# [I 2024-11-12 18:57:11,480] Trial 0 finished with value: 0.6989110708236694 and parameters: {'document_loader_index': 2, 'chunking_strategy_index': 0, 'chunk_size': 1000, 'embedding_model_index': 1}. Best is trial 0 with value: 0.6989110708236694.
# Trial 1/29
# [18:57:11] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=870553;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=790093;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.UNSTRUCTURED: 'unstructured'>,
#                     loader_kwargs=None, custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs={'separators': ['\n\n',
#                     '\n', ' ', '']}, custom_class=None), 'chunk_overlap': 100, 'chunk_size':
#                     1500, 'embedding_model': EmbeddingConfig(type=<EmbeddingModel.OPENAI:
#                     'openai'>, model_kwargs={'model': 'text-embedding-3-large'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/1',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.7178
# [I 2024-11-12 18:57:45,225] Trial 1 finished with value: 0.7177550182456062 and parameters: {'document_loader_index': 1, 'chunking_strategy_index': 0, 'chunk_size': 1500, 'embedding_model_index': 1}. Best is trial 1 with value: 0.7177550182456062.
# Trial 2/29
# [18:57:45] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=191573;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=893799;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYPDF: 'pypdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs={'separators': ['\n\n',
#                     '\n', ' ', '']}, custom_class=None), 'chunk_overlap': 100, 'chunk_size':
#                     500, 'embedding_model': EmbeddingConfig(type=<EmbeddingModel.OPENAI:
#                     'openai'>, model_kwargs={'model': 'text-embedding-3-large'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/2',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.6660
# [I 2024-11-12 18:58:14,515] Trial 2 finished with value: 0.665955542571961 and parameters: {'document_loader_index': 2, 'chunking_strategy_index': 0, 'chunk_size': 500, 'embedding_model_index': 1}. Best is trial 1 with value: 0.7177550182456062.
# Trial 3/29
# [18:58:14] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=800532;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=649503;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYPDF: 'pypdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs={'separators': ['\n\n',
#                     '\n', ' ', '']}, custom_class=None), 'chunk_overlap': 100, 'chunk_size':
#                     1000, 'embedding_model': EmbeddingConfig(type=<EmbeddingModel.OPENAI:
#                     'openai'>, model_kwargs={'model': 'text-embedding-3-large'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/3',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.6989110708236694                      ]8;id=853132;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=796063;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 18:58:14,524] Trial 3 finished with value: 0.6989110708236694 and parameters: {'document_loader_index': 2, 'chunking_strategy_index': 0, 'chunk_size': 1000, 'embedding_model_index': 1}. Best is trial 1 with value: 0.7177550182456062.
# Trial 4/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=163104;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=674166;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.UNSTRUCTURED: 'unstructured'>,
#                     loader_kwargs=None, custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs={'separators': ['\n\n',
#                     '\n', ' ', '']}, custom_class=None), 'chunk_overlap': 100, 'chunk_size':
#                     2000, 'embedding_model': EmbeddingConfig(type=<EmbeddingModel.OPENAI:
#                     'openai'>, model_kwargs={'model': 'text-embedding-3-large'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/4',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.7335
# [I 2024-11-12 18:58:44,326] Trial 4 finished with value: 0.7334579535506522 and parameters: {'document_loader_index': 1, 'chunking_strategy_index': 0, 'chunk_size': 2000, 'embedding_model_index': 1}. Best is trial 4 with value: 0.7334579535506522.
# Trial 5/29
# [18:58:44] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=581148;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=751068;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYPDF: 'pypdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/5',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# class_path:  ragbuilder.custom_components.CustomChunker
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=982519;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=619149;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [18:58:48] INFO     Use pytorch device_name: mps                                         ]8;id=83048;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=367991;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
#            INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=523526;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=567978;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8228
# [I 2024-11-12 18:59:44,982] Trial 5 finished with value: 0.8228296845678299 and parameters: {'document_loader_index': 2, 'chunking_strategy_index': 1, 'chunk_size': 500, 'embedding_model_index': 0}. Best is trial 5 with value: 0.8228296845678299.
# Trial 6/29
# [18:59:44] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=809763;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=697117;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYMUPDF: 'pymupdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.OPENAI: 'openai'>,
#                     model_kwargs={'model': 'text-embedding-3-large'}, custom_class=None),
#                     'vector_database': VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/6',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# Output()
# class_path:  ragbuilder.custom_components.CustomChunker
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.7382
# [I 2024-11-12 18:59:58,575] Trial 6 finished with value: 0.7381601147392043 and parameters: {'document_loader_index': 0, 'chunking_strategy_index': 1, 'chunk_size': 1500, 'embedding_model_index': 1}. Best is trial 5 with value: 0.8228296845678299.
# Trial 7/29
# [18:59:58] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=261100;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=759186;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYMUPDF: 'pymupdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs={'separators': ['\n\n',
#                     '\n', ' ', '']}, custom_class=None), 'chunk_overlap': 100, 'chunk_size':
#                     1000, 'embedding_model': EmbeddingConfig(type=<EmbeddingModel.OPENAI:
#                     'openai'>, model_kwargs={'model': 'text-embedding-3-large'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/7',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.7004
# [I 2024-11-12 19:00:13,054] Trial 7 finished with value: 0.7003594400390746 and parameters: {'document_loader_index': 0, 'chunking_strategy_index': 0, 'chunk_size': 1000, 'embedding_model_index': 1}. Best is trial 5 with value: 0.8228296845678299.
# Trial 8/29
# [19:00:13] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=283217;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=810711;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.UNSTRUCTURED: 'unstructured'>,
#                     loader_kwargs=None, custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 1000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/8',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# class_path:  ragbuilder.custom_components.CustomChunker
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=82546;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=44554;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [19:00:16] INFO     Use pytorch device_name: mps                                         ]8;id=303702;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=506878;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [19:00:17] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=638248;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=934670;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8365
# [I 2024-11-12 19:01:21,207] Trial 8 finished with value: 0.8365160075003434 and parameters: {'document_loader_index': 1, 'chunking_strategy_index': 1, 'chunk_size': 1000, 'embedding_model_index': 0}. Best is trial 8 with value: 0.8365160075003434.
# Trial 9/29
# [19:01:21] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=259474;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=239277;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYPDF: 'pypdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 2000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.OPENAI: 'openai'>,
#                     model_kwargs={'model': 'text-embedding-3-large'}, custom_class=None),
#                     'vector_database': VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/9',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# Output()
# class_path:  ragbuilder.custom_components.CustomChunker
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.7488
# [I 2024-11-12 19:01:44,429] Trial 9 finished with value: 0.7487705385359636 and parameters: {'document_loader_index': 2, 'chunking_strategy_index': 1, 'chunk_size': 2000, 'embedding_model_index': 1}. Best is trial 8 with value: 0.8365160075003434.
# Trial 10/29
# [19:01:44] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=165191;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=238442;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.UNSTRUCTURED: 'unstructured'>,
#                     loader_kwargs=None, custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/10',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# class_path:  ragbuilder.custom_components.CustomChunker
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=641669;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=391835;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [19:01:48] INFO     Use pytorch device_name: mps                                         ]8;id=221784;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=189233;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [19:01:49] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=227183;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=776098;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8277
# [I 2024-11-12 19:02:54,705] Trial 10 finished with value: 0.827746057321155 and parameters: {'document_loader_index': 1, 'chunking_strategy_index': 1, 'chunk_size': 500, 'embedding_model_index': 0}. Best is trial 8 with value: 0.8365160075003434.
# Trial 11/29
# [19:02:54] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=453699;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=565473;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.UNSTRUCTURED: 'unstructured'>,
#                     loader_kwargs=None, custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/11',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.827746057321155                       ]8;id=981380;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=769426;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 19:02:54,748] Trial 11 finished with value: 0.827746057321155 and parameters: {'document_loader_index': 1, 'chunking_strategy_index': 1, 'chunk_size': 500, 'embedding_model_index': 0}. Best is trial 8 with value: 0.8365160075003434.
# Trial 12/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=644063;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=868446;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.UNSTRUCTURED: 'unstructured'>,
#                     loader_kwargs=None, custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/12',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.827746057321155                       ]8;id=786491;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=549933;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 19:02:54,780] Trial 12 finished with value: 0.827746057321155 and parameters: {'document_loader_index': 1, 'chunking_strategy_index': 1, 'chunk_size': 500, 'embedding_model_index': 0}. Best is trial 8 with value: 0.8365160075003434.
# Trial 13/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=593223;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=828184;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.UNSTRUCTURED: 'unstructured'>,
#                     loader_kwargs=None, custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 1000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/13',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8365160075003434                      ]8;id=194093;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=164162;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 19:02:54,802] Trial 13 finished with value: 0.8365160075003434 and parameters: {'document_loader_index': 1, 'chunking_strategy_index': 1, 'chunk_size': 1000, 'embedding_model_index': 0}. Best is trial 8 with value: 0.8365160075003434.
# Trial 14/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=69415;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=864096;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.UNSTRUCTURED: 'unstructured'>,
#                     loader_kwargs=None, custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/14',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# class_path:  ragbuilder.custom_components.CustomChunker
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=511937;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=805318;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [19:02:58] INFO     Use pytorch device_name: mps                                         ]8;id=147459;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=644806;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [19:02:59] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=763725;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=160534;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8375
# [I 2024-11-12 19:04:01,057] Trial 14 finished with value: 0.8374550926422355 and parameters: {'document_loader_index': 1, 'chunking_strategy_index': 1, 'chunk_size': 1500, 'embedding_model_index': 0}. Best is trial 14 with value: 0.8374550926422355.
# Trial 15/29
# [19:04:01] INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=354169;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=41517;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.UNSTRUCTURED: 'unstructured'>,
#                     loader_kwargs=None, custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/15',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8374550926422355                      ]8;id=954196;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=864623;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 19:04:01,093] Trial 15 finished with value: 0.8374550926422355 and parameters: {'document_loader_index': 1, 'chunking_strategy_index': 1, 'chunk_size': 1500, 'embedding_model_index': 0}. Best is trial 14 with value: 0.8374550926422355.
# Trial 16/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=263357;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=574247;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.UNSTRUCTURED: 'unstructured'>,
#                     loader_kwargs=None, custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/16',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8374550926422355                      ]8;id=1341;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=435020;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 19:04:01,105] Trial 16 finished with value: 0.8374550926422355 and parameters: {'document_loader_index': 1, 'chunking_strategy_index': 1, 'chunk_size': 1500, 'embedding_model_index': 0}. Best is trial 14 with value: 0.8374550926422355.
# Trial 17/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=3733;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=715460;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYMUPDF: 'pymupdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 1500, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/17',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
# class_path:  ragbuilder.custom_components.CustomChunker
# ...
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/24',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8444499783929648                      ]8;id=340707;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=872184;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 19:07:43,581] Trial 24 finished with value: 0.8444499783929648 and parameters: {'document_loader_index': 0, 'chunking_strategy_index': 1, 'chunk_size': 2000, 'embedding_model_index': 0}. Best is trial 20 with value: 0.8444499783929648.
# Trial 25/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=738178;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=3701;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYMUPDF: 'pymupdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 2000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/25',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8444499783929648                      ]8;id=257517;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=973024;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 19:07:43,590] Trial 25 finished with value: 0.8444499783929648 and parameters: {'document_loader_index': 0, 'chunking_strategy_index': 1, 'chunk_size': 2000, 'embedding_model_index': 0}. Best is trial 20 with value: 0.8444499783929648.
# Trial 26/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=496324;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=526418;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYMUPDF: 'pymupdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 2000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/26',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8444499783929648                      ]8;id=536889;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=825050;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 19:07:43,598] Trial 26 finished with value: 0.8444499783929648 and parameters: {'document_loader_index': 0, 'chunking_strategy_index': 1, 'chunk_size': 2000, 'embedding_model_index': 0}. Best is trial 20 with value: 0.8444499783929648.
# Trial 27/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=239059;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=411846;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYMUPDF: 'pymupdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 2000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/27',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8444499783929648                      ]8;id=347780;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=738628;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 19:07:43,651] Trial 27 finished with value: 0.8444499783929648 and parameters: {'document_loader_index': 0, 'chunking_strategy_index': 1, 'chunk_size': 2000, 'embedding_model_index': 0}. Best is trial 20 with value: 0.8444499783929648.
# Trial 28/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=73451;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=746947;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYMUPDF: 'pymupdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.CUSTOM: 'custom'>,
#                     chunker_kwargs=None,
#                     custom_class='ragbuilder.custom_components.CustomChunker'),
#                     'chunk_overlap': 100, 'chunk_size': 2000, 'embedding_model':
#                     EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE: 'huggingface'>,
#                     model_kwargs={'model_name': 'mixedbread-ai/mxbai-embed-large-v1'},
#                     custom_class=None), 'vector_database':
#                     VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/28',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Config already evaluated with score: 0.8444499783929648                      ]8;id=220586;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=234495;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#63\63]8;;\
# [I 2024-11-12 19:07:43,693] Trial 28 finished with value: 0.8444499783929648 and parameters: {'document_loader_index': 0, 'chunking_strategy_index': 1, 'chunk_size': 2000, 'embedding_model_index': 0}. Best is trial 20 with value: 0.8444499783929648.
# Trial 29/29
#            INFO     Trial parameters: {'input_source': 'uber_10k.pdf', 'test_dataset':          ]8;id=245298;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py\optimization.py]8;;\:]8;id=124987;file:///Users/aravind/KruxAI/ragbuilder/src/ragbuilder/data_ingest/optimization.py#192\192]8;;\
#                     'rag_test_data_1726600284.375674 uber10k_shortlist.csv', 'document_loader':
#                     LoaderConfig(type=<ParserType.PYMUPDF: 'pymupdf'>, loader_kwargs=None,
#                     custom_class=None), 'chunking_strategy':
#                     ChunkingStrategyConfig(type=<ChunkingStrategy.RECURSIVE:
#                     'RecursiveCharacterTextSplitter'>, chunker_kwargs={'separators': ['\n\n',
#                     '\n', ' ', '']}, custom_class=None), 'chunk_overlap': 100, 'chunk_size':
#                     2000, 'embedding_model': EmbeddingConfig(type=<EmbeddingModel.HUGGINGFACE:
#                     'huggingface'>, model_kwargs={'model_name':
#                     'mixedbread-ai/mxbai-embed-large-v1'}, custom_class=None),
#                     'vector_database': VectorDBConfig(type=<VectorDatabase.CHROMA: 'chroma'>,
#                     vectordb_kwargs={'persist_directory': 'chroma_sample2/29',
#                     'collection_metadata': {'hnsw:space': 'cosine'}}, custom_class=None),
#                     'sampling_rate': None}
#            INFO     Load pretrained SentenceTransformer:                                 ]8;id=281656;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=820157;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [19:07:47] INFO     Use pytorch device_name: mps                                         ]8;id=712386;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=298472;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
#            INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=945991;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=469396;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Trial Score: 0.8400
# [I 2024-11-12 19:08:50,115] Trial 29 finished with value: 0.8400242849001808 and parameters: {'document_loader_index': 0, 'chunking_strategy_index': 0, 'chunk_size': 2000, 'embedding_model_index': 0}. Best is trial 20 with value: 0.8444499783929648.
# Optimization Complete!
# Best Score: 0.8444
# Best Parameters:
# {
#     'document_loader': <ParserType.PYMUPDF: 'pymupdf'>,
#     'chunking_strategy': <ChunkingStrategy.CUSTOM: 'custom'>,
#     'chunk_size': 2000,
#     'embedding_model': <EmbeddingModel.HUGGINGFACE: 'huggingface'>
# }
# [19:08:50] INFO     Load pretrained SentenceTransformer:                                 ]8;id=787470;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=169245;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#113\113]8;;\
#                     mixedbread-ai/mxbai-embed-large-v1
# [19:08:53] INFO     Use pytorch device_name: mps                                         ]8;id=147003;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=922593;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#219\219]8;;\
# [19:08:54] INFO     2 prompts are loaded, with the keys: ['query', 'passage']            ]8;id=95967;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py\SentenceTransformer.py]8;;\:]8;id=607086;file:///opt/anaconda3/envs/ragbuilder/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py#231\231]8;;\
# Output()
# ✓ Pipeline execution complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
best_indexer.similarity_search_with_relevance_scores("What was the financial impact of the sale of Uber's ATG Business to Aurora in the first quarter of 2021?")
# Out:
# [(Document(metadata={'source': 'uber_10k.pdf'}, page_content="We entered into a commercial agreement with Aurora pursuant to which the parties will collaborate with best efforts to launch and commercialize self-driving vehicles on our ridesharing network. We also allowed unvested RSUs for Uber stock held by employees of the ATG Business that transferred to Aurora to continue to vest over the next 12 months contingent upon the employee remaining at Aurora. As a result, we recognized liabilities of $315 million as consideration for these future obligations to Aurora.\n\nThe sale of the ATG Business did not represent a strategic shift that would have had a major effect on our operations and financial results, and therefore does not qualify for reporting as a discontinued operation. The resulting gain on disposal was recorded in other income (expense), net in the consolidated statements of operations.\n\nThe following table presents the gain on sale of the ATG Business (in millions):\n\nYear Ended December 31, 2021\n\nFair value of common shares received Derecognition of ATG Business' non-controlling interests Liability recognized for future obligations\n\n$\n\n1,277 1,057 (315)\n\nNet consideration received for sale of the ATG Business\n\nCarrying value of net assets transferred\n\nGain on the sale of the ATG Business\n\n$\n\n2,019 (375) 1,644\n\nNote 19 – Restructuring and Related Charges\n\nDuring the second quarter of 2020, we initiated and completed certain restructuring activities in order to reduce our overall cost structure in response to the economic challenges and uncertainty resulting from the COVID-19 pandemic and its impact on our business. We also exited the JUMP business and incurred costs related to site closures, asset impairments and write-offs.\n\nThe following table presents the total restructuring and related charges associated with our segments as well as corporate charges (in millions):\n\n138\n\nYear Ended December 31, 2020\n\nMobility Delivery\n\n$\n\n67 32\n\nFreight All Other\n\n(1)\n\nTotal restructuring and related charges by segment"),
#   0.816929672932209),
#  (Document(metadata={'source': 'uber_10k.pdf'}, page_content='The JUMP Divestiture did not represent a strategic shift that would cause a major effect on our operations and financial results, and therefore does not qualify for reporting as a discontinued operation for financial reporting purposes. The resulting loss on disposal was not material to us and was recorded in other income (expense), net, in the consolidated statements of operations during the second quarter of 2020.\n\nDivestiture of ATG Business to Aurora\n\nOn January 19, 2021, we completed the previously announced sale of our ATG Business, a subsidiary focused on the development and commercialization of autonomous vehicle technology, to Aurora. As a result, our controlling interest and the non-controlling interests in the ATG Business were settled, and ownership of the ATG Business transferred to Aurora.\n\nAs consideration for the sale, Aurora issued Series U-1 preferred shares to the third party investors of the ATG Business to settle their ATG Series A Stated Liquidation Preference of $1.1 billion, which had previously been recorded as redeemable and non-redeemable non-controlling interests on our consolidated balance sheet prior to this transaction. We received the residual consideration from the sale as the only common unit holder of the ATG Business in the form of Aurora common shares valued at $1.3 billion, representing 22% of fully-diluted (25% undiluted) ownership interest of Aurora. Concurrently, we invested $400 million in Aurora in exchange for Aurora Series U-2 convertible preferred shares, representing 4% of fully-diluted (5% undiluted) ownership interest of Aurora. Refer to Note 3 – Investments and Fair Value Measurement for additional information.\n\nWe do not consolidate Aurora under either the VIE or the voting interest model. For further information, refer to Note 15 – Variable Interest Entities.'),
#   0.7380010008274713),
#  (Document(metadata={'source': 'uber_10k.pdf'}, page_content='In January 2021, we sold our ATG Business to Aurora. Our ATG Business was included in the ATG and Other Technology Programs segment prior to this transaction. As a result of the sale, ATG and Other Technology Programs segment was no longer a reportable segment. Beginning in the first quarter of 2021, results of ATG and Other Technology Programs are included within All Other. Refer to Note 18 – Divestitures for further information regarding the sale of our ATG Business.\n\nAs of December 31, 2022, our three operating and reportable segments are as follows:\n\nSegment\n\nDescription\n\nMobility\n\nMobility products connect consumers with Drivers who provide rides in a variety of vehicles, such as cars, auto rickshaws, motorbikes, minibuses, or taxis. Mobility also includes activity related to our financial partnerships products and advertising.\n\nDelivery\n\nDelivery offerings allow consumers to search for and discover local restaurants, order a meal, and either pick-up at the restaurant or have the meal delivered. In certain markets, Delivery also includes offerings for grocery, alcohol and convenience store delivery as well as select other goods.\n\nFreight\n\nFreight connects Carriers with Shipper’s shipments available on our platform, and gives Carriers upfront, transparent pricing and the ability to book a shipment. Freight also includes transportation management and other logistics services offerings.\n\nFor information about how our reportable segments derive revenue, as well as revenue grouped by offerings and geographical region refer to Note 2 –\n\nRevenue.\n\n119\n\n2022\n\n30,458 18,250 98,167 20,039 2,606 — 3,878 73 173,471'),
#   0.715137779712677),
#  (Document(metadata={'source': 'uber_10k.pdf'}, page_content='126\n\nAurora\n\nIn January 2021, we sold our ATG Business to Aurora. After the sale, we held equity interests in Aurora through our Aurora Investments. As of December 31, 2021, our Aurora Investments had a fair value of $3.4 billion within investments on the consolidated balance sheet. Refer Note 3 – Investments and Fair Value Measurement for additional information regarding the accounting for our Aurora Investments and Note 18 – Divestitures for additional information regarding the sale of our ATG Business.\n\nAfter the sale in January 2021, we initially determined Aurora was a VIE as it lacked sufficient equity to finance its activities without future subordinated financial support. We were exposed to Aurora’s economic risks and rewards through our equity interests, which represented variable interests. On November 3, 2021, Aurora completed its planned SPAC merger with Reinvent Technology Partners Y, making Aurora a publicly traded company post combination, which triggered a reconsideration event. We reevaluated if Aurora still met the definition of a VIE and determined that Aurora was no longer a VIE when it completed its SPAC merger given it had sufficient equity to operate without the need for subordinated financial support.\n\nMoove'),
#   0.7059016823768616)]
